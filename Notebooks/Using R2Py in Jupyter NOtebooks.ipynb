# %% [markdown]
# # Using R in a Jupyter  Notebook with R2Py
#
# ![R](http://www.sciviews.org/_style/img/RLogo.png)
#
# This notebook was authored using a Python 2 kernel, running in a Docker container generated by the Dockerfile https://github.com/cfljam/pyRat/blob/master/Dockerfile
#
# Links
# ----
#
# - http://rpy.sourceforge.net/
# - http://rpy.sourceforge.net/rpy2/doc-2.4/html/interactive.html#module-rpy2.ipython.rmagic

# %%
## Load up R2 python interface so we can use R
# %load_ext rpy2.ipython
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%R
# library(dplyr)
# library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# %%R
# Sys.info()
# Out:
#                               sysname                               release
#                               "Linux"                   "4.0.3-boot2docker"
#                               version                              nodename
# "#1 SMP Wed May 13 20:54:49 UTC 2015"                        "6cf4f370e908"
#                               machine                                 login
#                              "x86_64"                             "unknown"
#                                  user                        effective_user
#                                "root"                                "root"

# %%
# %%R
# diamonds %>% head
# Out:
#   carat       cut color clarity depth table price    x    y    z
# 1  0.23     Ideal     E     SI2  61.5    55   326 3.95 3.98 2.43
# 2  0.21   Premium     E     SI1  59.8    61   326 3.89 3.84 2.31
# 3  0.23      Good     E     VS1  56.9    65   327 4.05 4.07 2.31
# 4  0.29   Premium     I     VS2  62.4    58   334 4.20 4.23 2.63
# 5  0.31      Good     J     SI2  63.3    58   335 4.34 4.35 2.75
# 6  0.24 Very Good     J    VVS2  62.8    57   336 3.94 3.96 2.48

# %%
# %%R
# diamonds %>% ggplot(aes(x=carat,y=price)) + geom_point(aes(color=cut))
